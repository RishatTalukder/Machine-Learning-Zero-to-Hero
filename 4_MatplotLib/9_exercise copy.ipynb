# %% [markdown]
# # Exercise
#
# Run the following code in your notebook
#
# > Don't run the other cells because the plots will be gone. Only run after you have written the solution for the exercise.

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import MatPlotLib

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * Use figure to create a figure object called fig.
# * add an axes to that figure object called ax with canvas size [0,0,1,1].
# * Plot the graph you see below.

# %%
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# **Create a Figure object and add two axes to it**

# %% [markdown]
# **Now plot (x,y) on both axes**

# %% [markdown]
# **Make a figure to compare (x,y) and (x,z)**

# %%
# Out:
# Text(0.5, 1.0, 'zoom')

# %% [markdown]
# ## Exercise 4
#
# **Make a figure with  2 subplots**

# %% [markdown]
# **Pplot (x,y) and (x,z) on the axes like the plot below**

# %% [markdown]
# **Resize and add lebels to the plot above**

# %%
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# Well done! I hope you enjoyed that!
